# %%
import pandas as pd

# %%
df = pd.read_csv('data-for-data-science-assignment.csv')

# %%
dataset = df.iloc[:, [3, 4]].drop_duplicates().values

# %%
df[:20].iloc[:, [3, 4]].drop_duplicates().values
# Out:
# array([[48.900273  ,  2.230193  ],
#        [48.900578  ,  2.229933  ],
#        [48.89885   ,  2.223466  ],
#        [48.88337326,  2.32924986]])

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

X = df.iloc[:, [3, 4]].drop_duplicates().values

# Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 15):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 15), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Training the K-Means model on the dataset
kmeans = KMeans(n_clusters = 50, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)

# %%
y_kmeans
# Out:
# array([11, 11, 11, ..., 25, 10, 25])

# %%
X
# Out:
# array([[48.900273,  2.230193],
#        [48.900578,  2.229933],
#        [48.89885 ,  2.223466],
#        ...,
#        [48.836634,  2.271548],
#        [48.836726,  2.271951],
#        [48.833896,  2.271057]])

# %%
X[:,0]
# Out:
# array([48.900273, 48.900578, 48.89885 , ..., 48.836634, 48.836726,
#        48.833896])

# %%
cluster = pd.DataFrame({'lat': X[:,0], 'lng': X[:,1], 'cluster_id': y_kmeans})

# %%
cluster.to_csv('cluster.csv', index = False)

# %%
df.count()
# Out:
# time             7572972
# scooter_id       7572972
# vendor           7572972
# lat              7572972
# lng              7572972
# battery_level    7572972
# dtype: int64

# %%
df.describe()
# Out:
#                 lat           lng  battery_level
# count  7.572972e+06  7.572972e+06   7.572972e+06
# mean   4.885986e+01  2.334190e+00   7.676042e+01
# std    1.484509e-02  3.028152e-02   2.184711e+01
# min    4.877982e+01  2.188531e+00   0.000000e+00
# 25%    4.884946e+01  2.311816e+00   6.100000e+01
# 50%    4.885982e+01  2.336217e+00   8.100000e+01
# 75%    4.887033e+01  2.353835e+00   9.700000e+01
# max    4.899008e+01  2.463192e+00   1.010000e+02

# %%
df.head()
# Out:
#                           time                scooter_id vendor        lat  \
# 0  2019-04-09 19:03:07.809 UTC  dGllcjpTQ09PVEVSOjE5NjE1   Tier  48.900273
# 1  2019-04-09 18:03:04.599 UTC  dGllcjpTQ09PVEVSOjE5NjE1   Tier  48.900273
# 2  2019-04-09 19:03:01.263 UTC  dGllcjpTQ09PVEVSOjE5NjE1   Tier  48.900273
# 3  2019-04-09 18:03:13.194 UTC  dGllcjpTQ09PVEVSOjE5NjE1   Tier  48.900273
# 4  2019-04-09 18:03:09.912 UTC  dGllcjpTQ09PVEVSOjE5NjE1   Tier  48.900273
#
#         lng  battery_level
# 0  2.230193              0
# 1  2.230193              0
# 2  2.230193              0
# 3  2.230193              0
# 4  2.230193              0

# %%
df[:1000].to_csv('data.csv', index = False)

# %%
df[df.vendor == 'Bird'].sort_values('time').head(20)
# Out:
#                                 time                            scooter_id  \
# 3064325  2019-03-01 13:23:45.988 UTC  7830439d-b497-4c96-93bd-e478e3f1f0a2
# 3064355  2019-03-01 13:23:46.236 UTC  a0e529e7-9eb8-473a-a847-6299ee314980
# 3064366  2019-03-01 13:23:46.236 UTC  4105dbc7-4fe4-4c79-a134-abef31b34ee3
# 3064370  2019-03-01 13:23:46.236 UTC  15de4137-d221-4ff2-8e70-73af79ce514a
# 5996702  2019-03-01 13:23:46.452 UTC  cb532775-e796-46c0-9faf-38616a5cb1ea
# 5996705  2019-03-01 13:23:46.452 UTC  000fbc0b-bb0d-4813-9936-8c15c01c4596
# 5996716  2019-03-01 13:23:46.452 UTC  4595d697-2b58-4eca-a9e9-2cd33d584565
# 5996741  2019-03-01 13:23:46.452 UTC  ff3be845-afd6-4e7e-a5e8-4e24f5772c0f
# 5996744  2019-03-01 13:23:46.452 UTC  a217163c-10db-4ea4-91e4-a90e594bb1cc
# 5996748  2019-03-01 13:23:46.452 UTC  d3b09370-e03f-4738-a0e9-d4eaaf22cf8f
# 3064306  2019-03-01 13:23:46.749 UTC  02cdabe2-93fa-4936-b9e6-46a2d0fb49f1
# ...

# %%
df[df.vendor == 'Lime'].time.drop_duplicates().count()
# Out:
# 22541

# %%
df.time.min()
# Out:
# '2019-03-01 00:00:08.338 UTC'

# %%
df.time.max()
# Out:
# '2019-04-09 23:02:56.619 UTC'

# %%
df.scooter_id.drop_duplicates().count()
# Out:
# 416936

# %%
df.groupby(['time', 'vendor']).count().sort_values('scooter_id')
# Out:
#                                     scooter_id  lat  lng  battery_level
# time                        vendor
# 2019-04-09 23:02:56.619 UTC Wind             1    1    1              1
# 2019-03-28 22:04:14.653 UTC Voi              1    1    1              1
# 2019-03-28 22:04:14.793 UTC Voi              1    1    1              1
# 2019-03-28 22:04:15.086 UTC Tier             1    1    1              1
#                             Wind             1    1    1              1
# ...                                        ...  ...  ...            ...
# 2019-04-02 15:03:17.038 UTC Bird           197  197  197            197
# 2019-03-24 10:02:03.749 UTC Bird           199  199  199            199
# 2019-03-29 20:02:55.781 UTC Bird           201  201  201            201
# 2019-04-07 15:03:17.832 UTC Bird           203  203  203            203
# 2019-03-24 16:01:19.162 UTC Bird           203  203  203            203
#
# [1172245 rows x 4 columns]

# %%
df[(df.vendor == 'Bird') & (df.time == '2019-03-24 16:01:19.162 UTC')].head(20)
# Out:
#                                 time                            scooter_id  \
# 3787992  2019-03-24 16:01:19.162 UTC  01861e9d-42a2-4af0-9376-a8311e4fb146
# 3787993  2019-03-24 16:01:19.162 UTC  0340d1e3-a545-4d10-b5f7-169aab37c203
# 3787994  2019-03-24 16:01:19.162 UTC  04434335-9669-435c-af40-f908b7f7f5dd
# 3787995  2019-03-24 16:01:19.162 UTC  072c7e35-0b4b-4505-af6e-2fd70797b2f2
# 3787996  2019-03-24 16:01:19.162 UTC  09109627-cd47-4f56-ba04-66854c619c7f
# 3787997  2019-03-24 16:01:19.162 UTC  0938ffb6-d1ee-47c7-b1cf-0dbb210faeae
# 3787998  2019-03-24 16:01:19.162 UTC  093be9ea-a602-4e9f-8be5-a9b8d921a2ed
# 3787999  2019-03-24 16:01:19.162 UTC  0b0d0ad2-dffa-4015-95f4-c37c82698925
# 3788000  2019-03-24 16:01:19.162 UTC  0c997686-0c77-45e4-801f-6164dfa6984a
# 3788001  2019-03-24 16:01:19.162 UTC  0ea52f73-325a-4e74-b90f-742319465d9d
# 3788002  2019-03-24 16:01:19.162 UTC  10baf163-410e-48bb-ad99-e10951087289
# ...

# %%
df.groupby('vendor').count()
# Out:
#            time  scooter_id      lat      lng  battery_level
# vendor
# Bird    2087177     2087177  2087177  2087177        2087177
# Bolt      68067       68067    68067    68067          68067
# Flash    936605      936605   936605   936605         936605
# Hive     744581      744581   744581   744581         744581
# Lime     264939      264939   264939   264939         264939
# Tier     777971      777971   777971   777971         777971
# Voi     1857630     1857630  1857630  1857630        1857630
# Wind     836002      836002   836002   836002         836002

# %%
df[(df.scooter_id == "aGl2ZTpTQ09PVEVSOjEzNTk0")].sort_values('time').to_csv('data.csv', index = False)

# %%
from math import sin, cos, sqrt, atan2, radians

# approximate radius of earth in km
R = 6373.0

lat1 = radians(48.83705)
lon1 = radians(2.371451)
lat2 = radians(48.8297)
lon2 = radians(2.37151)

dlon = lon2 - lon1
dlat = lat2 - lat1

a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
c = 2 * atan2(sqrt(a), sqrt(1 - a))

distance = R * c

print("Result:", distance)
# Out:
# Result: 0.8175506869288813
